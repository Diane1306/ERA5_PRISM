# %%
import folium
import numpy as np

# %%
m = folium.Map(location=[42.5, -87.75])
folium.vector_layers.Rectangle(bounds=[(42.625,-88.125),(42.375,-88.125),(42.375,-87.875),(42.625,-87.875)]).add_to(m)
folium.vector_layers.Rectangle(bounds=[(42.625,-87.625),(42.375,-87.625),(42.375,-87.875),(42.625,-87.875)]).add_to(m)
folium.Marker(location=[42.5, -87.75],icon=folium.Icon(icon='cloud',color='green')).add_to(m)
folium.Marker(location=[42.5, -88.0],icon=folium.Icon(icon='cloud')).add_to(m)
folium.Marker(location=[42.441000, -87.832889],icon=folium.Icon(color='red')).add_to(m)
folium.vector_layers.Rectangle(bounds=[(42.35,-87.85),(42.45,-87.85),(42.35,-87.75),(42.45,-87.75)]).add_to(m)
folium.vector_layers.Rectangle(bounds=[(42.35,-87.75),(42.45,-87.75),(42.35,-87.65),(42.45,-87.65)]).add_to(m)
folium.Marker(location=[42.4, -87.8],icon=folium.Icon(icon='cloud',color='green')).add_to(m)
folium.Marker(location=[42.4, -87.7],icon=folium.Icon(icon='cloud')).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map(location=[42.67, -84.49])
folium.vector_layers.Rectangle(bounds=[(42.65,-84.45),(42.75,-84.55)]).add_to(m)
folium.Marker(location=[42.7, -84.5],icon=folium.Icon(icon='cloud',color='blue')).add_to(m)
folium.Marker(location=[42.67, -84.49],icon=folium.Icon(color='red')).add_to(m)

folium.vector_layers.Rectangle(bounds=[(42.95,-85.55),(42.85,-85.45)]).add_to(m)
folium.Marker(location=[42.9, -85.5],icon=folium.Icon(icon='cloud',color='blue')).add_to(m)
folium.Marker(location=[42.881, -85.523],icon=folium.Icon(color='red')).add_to(m)

folium.vector_layers.Rectangle(bounds=[(44.85,-84.65),(44.95,-84.75)]).add_to(m)
folium.Marker(location=[44.9, -84.7],icon=folium.Icon(icon='cloud',color='blue')).add_to(m)
folium.Marker(location=[44.91, -84.72],icon=folium.Icon(color='red')).add_to(m)

folium.vector_layers.Rectangle(bounds=[(42.45,-86.35),(42.35,-86.25)]).add_to(m)
folium.Marker(location=[42.4, -86.3],icon=folium.Icon(icon='cloud',color='blue')).add_to(m)
folium.Marker(location=[42.36, -86.29],icon=folium.Icon(color='red')).add_to(m)

folium.vector_layers.Rectangle(bounds=[(44.65,-85.65),(44.75,-85.55)]).add_to(m)
folium.Marker(location=[44.7, -85.6],icon=folium.Icon(icon='cloud',color='blue')).add_to(m)
folium.Marker(location=[44.742, -85.582],icon=folium.Icon(color='red')).add_to(m)

folium.vector_layers.Rectangle(bounds=[(45.05,-85.75),(44.95,-85.65)]).add_to(m)
folium.Marker(location=[45.0, -85.7],icon=folium.Icon(icon='cloud',color='blue')).add_to(m)
folium.Marker(location=[45.03, -85.67],icon=folium.Icon(color='red')).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
[50, -105, 35, -75]
lat = np.linspace(38,50,121)
lon = np.linspace(-97,-80,171)
LAT, LON = np.meshgrid(lat,lon)
m = folium.Map(location=[44, -88.5])
for i in lat:
    for j in lon:
        folium.vector_layers.Rectangle(bounds=[(i-.05,j-.05),(i+.05,j+.05)]).add_to(m)
#         folium.Marker(location=[i,j],icon=folium.Icon(icon='cloud',color='blue')).add_to(m)
m
